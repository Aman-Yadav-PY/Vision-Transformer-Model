# %%
from torchvision.models import efficientnet_v2_s, EfficientNet_V2_S_Weights
from torchvision.datasets import Food101
from torchvision.transforms import transforms
from modelpipe import DataPipeLine

# %%
base_model = efficientnet_v2_s(weights=EfficientNet_V2_S_Weights.IMAGENET1K_V1)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_v2_s-dd5fe13b.pth" to C:\Users\amany/.cache\torch\hub\checkpoints\efficientnet_v2_s-dd5fe13b.pth
# 100.0%
